# %%
import pandas as pd
import numpy as np

datos = pd.read_csv("athlete_events.csv")

# %%
datos
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
datos["Sex"].unique().tolist()
# Out:
# ['M', 'F']

# %%
datos["Sport"]=="Judo"
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Name: Sport, Length: 271116, dtype: bool

# %%
datosJudo = datos[datos["Sport"]=="Judo"]
datosJudo
# Out:
#             ID                       Name Sex   Age  Height  Weight  \
# 1            2                   A Lamusi   M  23.0   170.0    60.0
# 160         64             M'Bairo Abakar   M  31.0     NaN     NaN
# 180         78               Salim Abanoz   M  26.0     NaN     NaN
# 412        229       Mohamed Ali Abdelaal   M  26.0   175.0    81.0
# 435        242          Ahmed Abdelrahman   M  20.0   165.0    60.0
# ...        ...                        ...  ..   ...     ...     ...
# 270853  135459             Oleg Zurabiani   M  19.0   172.0    64.0
# 270918  135482                Goran uvela   M  27.0   184.0    93.0
# 270981  135503            Zurab Zviadauri   M  23.0   182.0    90.0
# 271032  135535  Claudia Antoinette Zwiers   F  22.0   181.0    78.0
# 271033  135535  Claudia Antoinette Zwiers   F  30.0   181.0    78.0
#
#                 Team  NOC        Games  Year  Season            City Sport  \
# ...

# %%
datosFut = datos[datos["Sport"]=="Football"]
datosFut
# Out:
#             ID                               Name Sex   Age  Height  Weight  \
# 2            3                Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 105         37                 Ann Kristin Aarnes   F  23.0   182.0    64.0
# 116         41                           Rolf Aas   M  28.0     NaN     NaN
# 157         61                   Stefan Abadzhiev   M  26.0   175.0    72.0
# 178         76         Jouan Patrice Abanda Etong   M  22.0   185.0    82.0
# ...        ...                                ...  ..   ...     ...     ...
# 270810  135438               Manuel Ziga Fernndez   M  20.0   172.0    69.0
# 270843  135455                    Vjekoslav upani   M  19.0     NaN     NaN
# 270901  135476                  Emily Jane Zurrer   F  21.0   179.0    69.0
# 270982  135504  Viktor Oleksandrovych Zviahintsev   M  25.0   178.0    79.0
# 271107  135566         James Francis "Jim" Zylker   M  21.0   175.0    75.0
#
# ...

# %%
datosFut["Sex"].count()
# Out:
# 6745

# %%
datosFut["Sex"].value_counts()
# Out:
# M    5733
# F    1012
# Name: Sex, dtype: int64

# %%
datosFut["Age"].max()
# Out:
# 40.0

# %%
datosFut["Age"].min()
# Out:
# 15.0

# %%
datosFut[datosFut["Age"]==15]
# Out:
#             ID                                     Name Sex   Age  Height  \
# 128439   64677                      Samuel Osei Kuffour   M  15.0   175.0
# 156711   78727                        Louis John Menges   M  15.0     NaN
# 180261   90593                        Chatchai Paholpat   M  15.0   169.0
# 188957   94914                      Chirawat Pimpawatin   M  15.0   166.0
# 208319  104558  Abdel-Karim Muhammad Mahmoud Ezzat Sakr   M  15.0     NaN
#
#         Weight                           Team  NOC        Games  Year  Season  \
# 128439    75.0                          Ghana  GHA  1992 Summer  1992  Summer
# 156711     NaN  Christian Brothers' College-1  USA  1904 Summer  1904  Summer
# 180261    54.0                       Thailand  THA  1968 Summer  1968  Summer
# 188957    60.0                       Thailand  THA  1968 Summer  1968  Summer
# 208319     NaN                          Egypt  EGY  1936 Summer  1936  Summer
#
# ...

# %%
datosFut[datosFut["Age"]==40]
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 155668   78145  Margarete Maria "Meg" Pioresan   F  40.0   175.0    64.0
# 262097  131136                    Oros Witarsa   M  40.0     NaN     NaN
#
#              Team  NOC        Games  Year  Season       City     Sport  \
# 155668     Brazil  BRA  1996 Summer  1996  Summer    Atlanta  Football
# 262097  Indonesia  INA  1956 Summer  1956  Summer  Melbourne  Football
#
#                             Event Medal
# 155668  Football Women's Football   NaN
# 262097    Football Men's Football   NaN

# %%
OrdAge = datosFut.sort_values(by=["Weight"])
OrdAge
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 268586  134370  Albert Ferdinand "Al" Zerhusen   M  24.0   183.0    28.0
# 103855   52546             Tawa Bolanle Ishola   F  19.0   160.0    45.0
# 164358   82510         Linda Maserame Motlhalo   F  18.0   162.0    47.0
# 196365   98583         Lebohang Ester Ramalepe   F  24.0   155.0    48.0
# 176013   88475                      Vera Okolo   F  19.0   161.0    48.0
# ...        ...                             ...  ..   ...     ...     ...
# 270443  135272                      Zou Wenzhi   M   NaN     NaN     NaN
# 270478  135289            Zzimo Alves Calazans   M  20.0     NaN     NaN
# 270661  135361     Abdullah Sulaiman Zubromawi   M  22.0   176.0     NaN
# 270718  135386                      Enea Zuffi   M  20.0     NaN     NaN
# 270843  135455                 Vjekoslav upani   M  19.0     NaN     NaN
#
#                  Team  NOC        Games  Year  Season            City  \
# ...

# %%
OrdAge[OrdAge["Age"].notna()]
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 268586  134370  Albert Ferdinand "Al" Zerhusen   M  24.0   183.0    28.0
# 103855   52546             Tawa Bolanle Ishola   F  19.0   160.0    45.0
# 164358   82510         Linda Maserame Motlhalo   F  18.0   162.0    47.0
# 196365   98583         Lebohang Ester Ramalepe   F  24.0   155.0    48.0
# 176013   88475                      Vera Okolo   F  19.0   161.0    48.0
# ...        ...                             ...  ..   ...     ...     ...
# 269620  134916             Alfredo J. Zibecchi   M  28.0     NaN     NaN
# 270478  135289            Zzimo Alves Calazans   M  20.0     NaN     NaN
# 270661  135361     Abdullah Sulaiman Zubromawi   M  22.0   176.0     NaN
# 270718  135386                      Enea Zuffi   M  20.0     NaN     NaN
# 270843  135455                 Vjekoslav upani   M  19.0     NaN     NaN
#
#                  Team  NOC        Games  Year  Season            City  \
# ...

# %%
# Out:
#             ID                               Name Sex   Age  Height  Weight  \
# 105         37                 Ann Kristin Aarnes   F  23.0   182.0    64.0
# 178         76         Jouan Patrice Abanda Etong   M  22.0   185.0    82.0
# 268        139             George "Ioannis" Abbot   M   NaN     NaN     NaN
# 663        385                 Max "Xam" Abegglen   M  22.0     NaN     NaN
# 702        401            Abelardo Fernndez Antua   M  22.0     NaN     NaN
# ...        ...                                ...  ..   ...     ...     ...
# 269104  134653                        Zhao Lihong   F  23.0   168.0    55.0
# 269209  134708                Petar Petrov Zhekov   M  24.0   181.0    76.0
# 269620  134916                Alfredo J. Zibecchi   M  28.0     NaN     NaN
# 270189  135167                Wadysaw Antoni muda   M  22.0   187.0    84.0
# 270982  135504  Viktor Oleksandrovych Zviahintsev   M  25.0   178.0    79.0
#
# ...

# %%
datos = pd.read_csv("athlete_events.csv")

# %%
datos1 = datos[datos["Medal"].notna()]
datos1 = datos1[datos1["Age"]==datos1["Age"].max()]
print("Jugador mas veterano que ha ganado medalla es:")
datos1
# Out:
# Jugador mas veterano que ha ganado medalla es:
#           ID                                           Name Sex   Age  Height  \
# 44584  22984  John (Herbert Crawford-) Copley (Williamson-)   M  73.0     NaN
#
#        Weight           Team  NOC        Games  Year  Season    City  \
# 44584     NaN  Great Britain  GBR  1948 Summer  1948  Summer  London
#
#                   Sport                                          Event   Medal
# 44584  Art Competitions  Art Competitions Mixed Painting, Graphic Arts  Silver

# %%
datos2 = datos[datos["Medal"]=="Gold"]
datos2 = datos2[datos2["Age"]==datos2["Age"].min()]
print("Los jugadores mas jovenes que han ganado medalla de oro son:")
datos2
# Out:
# Los jugadores mas jovenes que han ganado medalla de oro son:
#             ID                                Name Sex   Age  Height  Weight  \
# 27207    14142                       Hans Bourquin   M  13.0     NaN     NaN
# 52010    26731  Donna Elizabeth de Varona (-Pinto)   F  13.0   168.0    61.0
# 73581    37398                          Fu Mingxia   F  13.0   160.0    48.0
# 78544    39866        Marjorie Gestring (-Redlick)   F  13.0     NaN     NaN
# 119277   60384                          Kim Yun-Mi   F  13.0   160.0    48.0
# 200704  100797       Aileen Muriel Riggin (-Soule)   F  13.0   142.0     NaN
# 268602  134381                         Klaus Zerta   M  13.0   165.0    48.0
#
#                  Team  NOC        Games  Year  Season         City  \
# 27207     Switzerland  SUI  1928 Summer  1928  Summer    Amsterdam
# 52010   United States  USA  1960 Summer  1960  Summer         Roma
# 73581           China  CHN  1992 Summer  1992  Summer    Barcelona
# ...

# %%
datos[datos["Medal"].notna()]["Name"].value_counts()
datos3 = datos[datos["Name"]=="Michael Fred Phelps, II"]
datos3.to_csv("medallistas.csv",header=True,index=True)
